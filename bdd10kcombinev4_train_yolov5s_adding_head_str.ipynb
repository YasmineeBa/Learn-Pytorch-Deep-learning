# %% [markdown]
# <a href="https://colab.research.google.com/github/YasmineeBa/Learn-Pytorch-Deep-learning/blob/main/bdd10kcombinev4_train_yolov5s_adding_head_str.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %ls /content/drive/MyDrive/yoloformat_kitti/
# Out:
# bdd100kv4_yolo_new.zip  model_yolov5-CA/
# bdd100kv4_yolo.zip      yoloformatkitti.zip

# %% [markdown]
# import the dataset

# %%
import shutil
shutil.copy('/content/drive/MyDrive/yoloformat_kitti/yoloformatkitti.zip', 'yoloformatkitti.zip')
# Out:
# 'yoloformatkitti.zip'

# %%
# !unzip yoloformatkitti.zip
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   inflating: dataset/train/images/000048.png
#   inflating: dataset/train/images/001611.png
#   inflating: dataset/train/images/001019.png
#   inflating: dataset/train/images/001207.png
#   inflating: dataset/train/images/003745.png
#   inflating: dataset/train/images/005273.png
#   inflating: dataset/train/images/001174.png
#   inflating: dataset/train/images/004154.png
#   inflating: dataset/train/images/003880.png
#   inflating: dataset/train/images/003872.png
#   inflating: dataset/train/images/004633.png
#   inflating: dataset/train/images/003417.png
#   inflating: dataset/train/images/005205.png
#   inflating: dataset/train/images/005930.png
#   inflating: dataset/train/images/005376.png
#   inflating: dataset/train/images/000458.png
#   inflating: dataset/train/images/002553.png
#   inflating: dataset/train/images/004793.png
#   inflating: dataset/train/images/001400.png
# ...

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# time its performance test yolov5s_kitti_adam lr=0.001 batch = 64
# %%time
# !python train.py --img 640 --project yolov5-kitti --upload_dataset --batch-size 64 --epochs 120 --save-period 1  --data data/bdd10k.yaml --cfg models/yolov5s.yaml  --weights 'yolov5s.pt' --cache --hyp hyp.scratch-low.yaml --name yolov5s_kitti
# Out:
# train: weights=yolov5s.pt, cfg=models/yolov5s.yaml, data=data/bdd10k.yaml, hyp=hyp.scratch-low.yaml, epochs=120, batch_size=64, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=Adam, sync_bn=False, workers=8, project=yolov5-kitti, name=yolov5s_kitti, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=1, seed=0, local_rank=-1, entity=None, upload_dataset=True, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-160-g867f7f0 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# time its performance test yolov5s_kitti_sgd lr=0.001 batch = 64
# %%time
# !python train.py --img 640 --project yolov5-kitti --upload_dataset --batch-size 64 --epochs 120 --save-period 1  --data data/bdd10k.yaml --cfg models/yolov5s.yaml  --weights 'yolov5s.pt' --cache --hyp hyp.scratch-low.yaml --name yolov5s_kitti
# Out:
# train: weights=yolov5s.pt, cfg=models/yolov5s.yaml, data=data/bdd10k.yaml, hyp=hyp.scratch-low.yaml, epochs=120, batch_size=64, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5-kitti, name=yolov5s_kitti, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=1, seed=0, local_rank=-1, entity=None, upload_dataset=True, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-160-g867f7f0 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !unzip /content/bdd100kv4_yolo.zip -d /content/bdd10k_dataset/

# %%
# !rm /content/bdd100kv4_yolo.zip

# %%
#download yolov5 repository
# !git clone https://github.com/ultralytics/yolov5

# !cd ./yolov5
# !pip install -r requirements.txt 
  # install dependencies (ignore errors)
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15639, done.
# remote: Counting objects: 100% (246/246), done.
# remote: Compressing objects: 100% (178/178), done.
# remote: Total 15639 (delta 120), reused 141 (delta 68), pack-reused 15393
# Receiving objects: 100% (15639/15639), 14.59 MiB | 30.06 MiB/s, done.
# Resolving deltas: 100% (10649/10649), done.
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !pip install wandb

# %%
import wandb
wandb.login()

# %%
# data yaml
path: ../bdd10k_dataset
train: ../bdd10k_dataset/train/
val: ../bdd10k_dataset/val/

nc: 9
names:
 0: bicycle
 1: person
 2: traffic sign
 3: traffic light
 4: car
 5: truck
 6: motorcycle
 7: bus
 8: train

# %%
# model
# %cd yolov5
# Out:
# /content/yolov5

# %%
# time its performance
# %%time
# !python train.py --img 640 --project yolov5s_head_str --upload_dataset --batch-size 40 --epochs 110 --save-period 1  --data data/bdd10k.yaml --cfg models/yolov5s.yaml  --weights 'yolov5s.pt' --cache --hyp hyp.scratch-low.yaml --name yolov5_original_sgd
# Out:
# train: weights=yolov5s.pt, cfg=models/yolov5s.yaml, data=data/bdd10k.yaml, hyp=hyp.scratch-low.yaml, epochs=110, batch_size=40, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5s_head_str, name=yolov5_original_sgd, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=1, seed=0, local_rank=-1, entity=None, upload_dataset=True, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-160-g867f7f0 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# time its performance
# %%time
# !python train.py --img 640 --project yolov5s_head_str --upload_dataset --batch-size 40 --epochs 160 --save-period 1  --data data/bdd10k.yaml --cfg models/yolov5s.yaml  --weights 'yolov5s.pt' --cache --hyp hyp.scratch-low.yaml --name yolov5_original_adam
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout) 2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# ...

# %% [markdown]
# #section

# %%
# time its performance
# %%time
# !python train.py --img 640 --project yolov5s_head_str --upload_dataset --batch-size 40 --epochs 160 --save-period 1  --data data/bdd10k.yaml --cfg models/yolov5s.yaml  --weights 'yolov5s.pt' --cache --hyp hyp.scratch-low.yaml --name yolov5s_head_str
# Out:
# requirements: YOLOv5 requirement "gitpython" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.5 MB/s eta 0:00:00
# ...
#
# requirements: 1 package updated per ['gitpython']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# ...

# %% [markdown]
# #section 4head+ c3str_finalhead

# %%
# time its performance
# %%time
# !python train.py --img 640 --project yolov5s_head_tr --upload_dataset --batch-size 40 --epochs 160 --save-period 1  --data data/bdd10k.yaml --cfg models/yolov5s.yaml  --weights 'yolov5s.pt' --cache --hyp hyp.scratch-low.yaml --name yolov5s_head_tr
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: Currently logged in as: computersciencevis2000 (usthbyassu). Use `wandb login --relogin` to force relogin
# train: weights=yolov5s.pt, cfg=models/yolov5s.yaml, data=data/bdd10k.yaml, hyp=hyp.scratch-low.yaml, epochs=160, batch_size=40, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=Adam, sync_bn=False, workers=8, project=yolov5s_head_tr, name=yolov5s_head_tr, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=1, seed=0, local_rank=-1, entity=None, upload_dataset=True, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# ...

# %%
# !python detect.py --weights /content/yolov5/yolov5s_head_tr/yolov5s_head_tr5/weights/best.pt --cnf 0.25 --source /content/
